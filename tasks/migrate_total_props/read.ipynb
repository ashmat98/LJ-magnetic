# %%
import pandas as pd
import os

# %%
files = os.listdir("/data/biophys/ashmat/LJ-magnetic/dfs")

# %%
pd.read_hdf(os.path.join("/data/biophys/ashmat/LJ-magnetic/dfs", files[0]))
# Out:
#                  N           Iz  omega_MLE  beta_MLE      total_L  \
# time
# 0.000000     199.0  6356.148438   0.724979  0.193786  4608.071289
# 0.100000     199.0  6369.051758   0.723510  0.166824  4608.071289
# 0.200000     199.0  6362.547852   0.724249  0.127969  4608.071289
# 0.300000     199.0  6336.895508   0.727181  0.105048  4608.071289
# 0.400000     199.0  6293.136719   0.732238  0.099146  4608.071289
# ...            ...          ...        ...       ...          ...
# 1999.599976  199.0  5798.187500   0.794743  0.149039  4608.071289
# 1999.699951  199.0  5809.501953   0.793196  0.139925  4608.071289
# 1999.800049  199.0  5835.190430   0.789704  0.119319  4608.071289
# 1999.900024  199.0  5874.226562   0.784456  0.103582  4608.071289
# 2000.000000  199.0  5925.055664   0.777726  0.098236  4608.071289
#
#                  total_E     total_KE      total_IE  collisions-1  \
# time
# 0.000000     8354.683594  3210.732666 -8.381932e-08           0.0
# ...
