# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import importlib
from simulator import SimulatorRotating, SimulatorMagnetic

from utils.runners import multirunner, runner

import multiprocessing
from multiprocessing import Pool, cpu_count

from utils.logs import get_logger
from utils.utils import beep
from tqdm.notebook import tqdm 
import datetime
import json

import sys, os, time
# logging.config.fileConfig("/home/amatevosyan/telegramLogConfig")
# logger = logging.getLogger("telegram")

# logger = multiprocessing.log_to_stderr()
# logger.setLevel(logging.WARNING)

# %%
params_model = {
#     "group_name" : "Ensemble 5",
    "class":"SimulatorRotating",
    "R" : 1.0,
    "Rz" : 0.25,
    "Bz" : 0,
    "eccentricity": 0.5,
    "sigma":0.1,
    "epsilon":0.1,
    "phi":0,
    "omega":0.
#     "get_logger" : get_logger
}
params_init = {
    "energy": 1,
    "sigma_grid":0.35,
    "position_random_shift_percentage": 0.0/100,
    # "angular_momentum_factor" : 0.,
    "angular_momentum" : 20,
    "planar": False,
    "zero_momentum": False,
}
params_simulation = {
    "iteration_time" : 500,
    "dt" : 1e-3,
    "record_interval" : 1e-2,
    "algorithm" : "VERLET",
}

sim = SimulatorRotating(**params_model)
sim.init_positions_closepack(**params_init)
sim.init_velocities(**params_init);
print(f"""
Angular momentum: {sim.angular_momentum(sim.r_init, sim.v_init)[2].sum():0.2f}
Total energy:     {sim.total_energy(sim.r_init, sim.v_init):0.3f}
    Interactions: {0.5*np.sum(sim.interaction_energy(sim.r_init, sim.v_init)):0.3f}
Particle number:  {sim.particle_number()}

Estimated time:   {sim.simulate_estimate(**params_simulation)["time"]},
        memory:   {sim.simulate_estimate(**params_simulation)["memory"]:0.1f}MB
 """)
# Out:
# Angular momentum: 20.00
# Total energy:     97.000
#     Interactions: -0.021
# Particle number:  97
#
# Estimated time:   0:16:40,
#         memory:   393.2MB

# %%
def callback(sim):
    return (sim.get_data_frames(), sim.get_history())

# %%
# runner(params_model,params_init,params_simulation,callback=callback)

# %%
n_ = cpu_count()
params = []
for epsilon in np.logspace(-2, 0, n_):
    params_model["epsilon"] = 0.1
    params.append( (params_model.copy(), params_init.copy(), params_simulation.copy()) )

# %%
res = multirunner(params, 
            callback=callback
            )
beep()
# Out:
# 100%|██████████| 500000/500000 [07:42<00:00, 1082.12it/s]
# 100%|██████████| 15/15 [01:15<00:00,  5.03s/it]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df = pd.DataFrame([(x["L"]).sum(axis=1) for x,_ in res]).T
df.loc[:].plot(alpha=0.1)
df.loc[:].mean(axis=1).plot()
plt.gca().get_legend().remove()
ax = plt.gca()

# %%
df = pd.DataFrame([(x["L"]).sum(axis=1) for x,_ in res]).T
df.loc[:].plot(alpha=0.1)
df.loc[:].mean(axis=1).plot()
plt.gca().get_legend().remove()
ax = plt.gca()

# %%
df = pd.DataFrame([x["Etotal"].sum(axis=1) for x,_ in res]).T
df.loc[:].plot(alpha=0.1)
df.loc[:].mean(axis=1).plot()
plt.gca().get_legend().remove()

# %%
dfs, hst = res[0]

# %%
hst.keys()
# Out:
# dict_keys(['time', 'rs', 'vs', 'KE', 'PE', 'IE', 'L', 'OMEGA', 'collisions', 'BInertia'])

# %%
zr = -hst["rs"] * hst["rs"][:,-1,None,:]
zr[:,-1,:] += (hst["rs"]**2).sum(axis=1)
Ltot = (hst["L"] + 0.5 * params_model["Bz"] * zr)

# %%
zr.shape
# Out:
# (5001, 3, 19)

# %%
Ltot.shape
# Out:
# (5001, 3, 19)

# %%
sim.abc
# Out:
# array([1., 1., 1.])

# %%
plt.plot(Ltot[:,2])
# Out:
# [<matplotlib.lines.Line2D at 0x7f4026816d60>,
#  <matplotlib.lines.Line2D at 0x7f4026816dc0>,
#  <matplotlib.lines.Line2D at 0x7f4026816df0>,
#  <matplotlib.lines.Line2D at 0x7f4026816ee0>,
#  <matplotlib.lines.Line2D at 0x7f4026816fd0>,
#  <matplotlib.lines.Line2D at 0x7f4026822100>,
#  <matplotlib.lines.Line2D at 0x7f40268221f0>,
#  <matplotlib.lines.Line2D at 0x7f40268222e0>,
#  <matplotlib.lines.Line2D at 0x7f40268223d0>,
#  <matplotlib.lines.Line2D at 0x7f40268224c0>,
#  <matplotlib.lines.Line2D at 0x7f4026816d90>,
#  <matplotlib.lines.Line2D at 0x7f40268225b0>,
#  <matplotlib.lines.Line2D at 0x7f40268226a0>,
#  <matplotlib.lines.Line2D at 0x7f4026822850>,
#  <matplotlib.lines.Line2D at 0x7f4026822940>,
#  <matplotlib.lines.Line2D at 0x7f4026822a30>,
#  <matplotlib.lines.Line2D at 0x7f4026822b20>,
#  <matplotlib.lines.Line2D at 0x7f4026822c10>,
#  <matplotlib.lines.Line2D at 0x7f4026822d00>]

# %%
hst["L"]
# Out:
# array([[[ 8.9676648e-01,  3.0624755e-03,  2.1568532e-01, ...,
#           2.4170989e-01,  1.4514927e-02,  9.1927510e-01],
#         [-3.5848882e-02,  5.3043631e-03, -4.1286409e-01, ...,
#          -3.9556211e-01,  2.5140591e-02, -3.5470884e-02],
#         [ 1.2682194e+00,  9.8404211e-01,  3.2908285e-01, ...,
#           3.2768869e-01,  9.8049957e-01,  1.3000513e+00]],
#
#        [[ 8.9357543e-01,  3.0432791e-03,  1.7492479e-01, ...,
#           2.0128636e-01,  1.4420583e-02,  9.1833556e-01],
#         [-1.2501630e-01,  5.2726748e-03, -4.3478778e-01, ...,
#          -4.1804066e-01,  2.4993416e-02, -1.2685429e-01],
#         [ 1.2562889e+00,  9.7631669e-01,  3.2609889e-01, ...,
#           3.2518238e-01,  9.7034502e-01,  1.2909222e+00]],
#
#        [[ 8.8922548e-01,  2.9851659e-03,  1.3484009e-01, ...,
#           1.6121975e-01,  1.4136036e-02,  9.1595674e-01],
#         [-2.1191630e-01,  5.1799440e-03, -4.5545647e-01, ...,
#          -4.3943214e-01,  2.4563681e-02, -2.1585555e-01],
#         [ 1.2282362e+00,  9.5533705e-01,  3.1867921e-01, ...,
#           3.1826586e-01,  9.4716477e-01,  1.2644725e+00]],
#
#        ...,
#
#        [[-4.2431450e-01,  5.8915856e-04, -3.7289017e-01, ...,
#          -3.8183072e-01,  2.3800782e-03, -4.2071152e-01],
#         [-5.9928298e-01, -7.5075827e-03,  2.9538564e-02, ...,
#          -1.2072814e-03, -3.5220385e-02, -5.9197819e-01],
#         [ 1.1728261e+00,  8.9957482e-01,  3.0197123e-01, ...,
#           2.9939607e-01,  9.0492386e-01,  1.1868646e+00]],
#
#        [[-5.0053835e-01,  4.2728643e-04, -3.8231841e-01, ...,
#          -3.9189512e-01,  1.6306111e-03, -4.9809548e-01],
#         [-5.7488549e-01, -7.3388447e-03,  6.9658354e-02, ...,
#           3.9390180e-02, -3.4398180e-02, -5.6993496e-01],
#         [ 1.2189469e+00,  9.3873745e-01,  3.1483907e-01, ...,
#           3.1246570e-01,  9.4187808e-01,  1.2386208e+00]],
#
#        [[-5.7537556e-01,  2.1738085e-04, -3.9100033e-01, ...,
#          -4.0130267e-01,  6.6194456e-04, -5.7400113e-01],
#         [-5.4991204e-01, -7.1134032e-03,  1.0934167e-01, ...,
#           7.9897337e-02, -3.3302750e-02, -5.4716009e-01],
#         [ 1.2508049e+00,  9.6651709e-01,  3.2383186e-01, ...,
#           3.2175827e-01,  9.6722400e-01,  1.2756606e+00]]], dtype=float32)

# %%
df.std(axis=1).plot(marker=".", lw=0)
plt.xscale("log");plt.yscale("log")
plt.grid()

# %%
start = 20
end = 100 #len(df)
x = np.log(df.loc[start:end].index.values)
y = np.log(df.std(axis=1).loc[start:end].values)
plt.plot(x,y)
slope, intercept = np.polyfit(x, y, 1)
plt.plot(x, x * slope + intercept, "--", c="k")
plt.title(f"slope = {slope:0.4f}")
# Out:
# Text(0.5, 1.0, 'slope = 0.8601')
